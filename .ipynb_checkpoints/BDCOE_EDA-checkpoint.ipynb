# %% [markdown]
# # `Spotify Features EDA`

# %% [markdown]
# - Here we have a datset that has different features of songs on spotify like popularity,acousticness, danceability,energy,etc.
# - I have performed EDA on this dataset and I have driven out some insights from this data.
# - Please find all the plots and insights below.

# %%
#Importing all the necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading the dataset
df = pd.read_csv('SpotifyFeatures.csv')

# %%
df
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
# Getting the number of rows and columns in the datset
df.shape
# Out:
# (232725, 18)

# %%
#Getting the mean,median,min,max and standard deviation of all the numerical data
df.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %% [markdown]
# ### `Checking for missing values`

# %%
#Getting the number of missing values column-wise
df.isna().sum()
# Out:
# genre               0
# artist_name         0
# track_name          1
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %% [markdown]
# - Since there is only one value missing in such a big data, so we should drop that row as it won't have a very big effect on the dataset

# %%
#Dropping the row with missing value
df = df.dropna(subset = ['track_name'])

# %%
#Checking if any other missing value remains
df.isna().sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
#Checking any duplicate values in the dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# ### `Comparing differnt song features with the popularity of the song`

# %%
#Creating a scatter plot to compare how acousticness affect popularity of the song
x = df['popularity']
y = df['acousticness']
plt.figure(figsize=(20,20))
plt.scatter(x,y)
plt.title('Scatter plot to compare how acousticness affect popularity of the song',fontsize=20)
plt.xlabel('Popularity', fontsize=20)
plt.ylabel('Acousticness', fontsize=20)
plt.show()

# %% [markdown]
# - `As we can see that the scatter plot is not able to show us any insights as there is a lot of data that needs to be processed.`

# %%
x = df['popularity']
y = df['acousticness']
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Acousticness')
plt.show()

# %%
x = df['popularity']
y = df['danceability']
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Danceability')
plt.show()

# %%
x = df['popularity']
y = df['energy']
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Energy')
plt.show()

# %%
x = df['popularity']
y = df['instrumentalness']
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Instrumentalness')
plt.show()

# %%
x = df['popularity']
y = df['liveness']
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Liveness')
plt.show()

# %%
x = df['popularity']
y = df['loudness']
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Loudness (in dB)')
plt.show()

# %%
x = df['popularity']
y = df['speechiness']*10
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Speechiness')
plt.show()

# %%
x = df['popularity']
y = df['valence']
plt.hexbin(x,y,gridsize=20,cmap='viridis')
plt.xlabel('Popularity')
plt.ylabel('Valence')
plt.show()

# %%
df.loc[:,'duration_sec'] = df['duration_ms']/1000

# %%
x = df['popularity']
y = df['duration_sec']
plt.figure(figsize=(20,20))
plt.scatter(x,y)
plt.xlabel('Popularity')
plt.ylabel('Duration of the track (in seconds)')
plt.show()

# %%
df_filtered = df[df['duration_sec']<1000]
x = df_filtered['popularity']
y = df_filtered['duration_sec']

plt.scatter(x,y)
plt.xlabel('Popularity')
plt.ylabel('Duration of the track (in seconds)')
plt.show()

# %%
x = df_filtered['popularity']
y = df_filtered['duration_sec']
plt.hexbin(x,y,gridsize=20)
plt.xlabel('Popularity')
plt.ylabel('Duration of the track (in seconds)')
plt.show()

# %%
df['artist_name'].nunique()
# Out:
# 14564

# %%
top_artists_max = (
    df.groupby("artist_name")["popularity"]
      .max()
      .sort_values(ascending=False)
      .head(10)
)
print(top_artists_max)
# Out:
# artist_name
# Ariana Grande    100
# Post Malone       99
# Daddy Yankee      98
# Sam Smith         97
# Marshmello        97
# Ava Max           97
# Pedro Capó        97
# Halsey            97
# DJ Snake          96
# Anuel Aa          96
# Name: popularity, dtype: int64

# %%
counts = df['genre'].value_counts()
label = counts.index
value = counts.values
plt.barh(label,value)
plt.show()

# %%
counts = df['key'].value_counts()
label = counts.index
value = counts.values
plt.barh(label,value,color='c')
plt.show()

# %%
genres = df["genre"].unique()
data = [df[df["genre"] == g]["popularity"].values for g in genres]

plt.figure(figsize=(14,6))
plt.boxplot(data, tick_labels=genres, patch_artist=True)

plt.xlabel("Genre")
plt.ylabel("Popularity")
plt.xticks(rotation=90)
plt.show()

# %%
keys = df["key"].unique()

data = [df[df["key"] == k]["popularity"].values for k in keys]

plt.figure(figsize=(12,6))
plt.boxplot(data, tick_labels=keys, patch_artist=True)

plt.xlabel("Key")
plt.ylabel("Popularity")
plt.xticks(rotation=0)
plt.show()

# %%
df_duration = df.groupby('genre')['duration_sec'].mean()
x = df_duration.index
y = df_duration.values
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()

# %%
df_duration = df.groupby('genre')['duration_sec'].max()
x = df_duration.index
y = df_duration.values
bars = plt.barh(x,y,color='#fa6305')
for i,val in enumerate(y):
    if (val>4000):
        bars[i].set_hatch('/')
plt.xticks(rotation=90)
plt.show()

# %%
df_artists = df.groupby('genre')['artist_name'].nunique()
x = df_artists.index
y = df_artists.values
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()
